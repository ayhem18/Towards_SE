# %%
import os
import pandas as pd

# %%
script_dir = os.getcwd()
output_dir = os.path.join(script_dir, "data")
places_file = os.path.join(output_dir, "fsq_places_sample.csv")
categories_file = os.path.join(output_dir, "fsq_categories_sample.csv")

df_places = pd.read_csv(places_file, nrows=10)
df_categories = pd.read_csv(categories_file)

# %%
df_places.columns
# Out:
# Index(['fsq_place_id', 'name', 'latitude', 'longitude', 'address', 'locality',
#        'region', 'postcode', 'admin_region', 'post_town', 'po_box', 'country',
#        'date_created', 'date_refreshed', 'date_closed', 'tel', 'website',
#        'email', 'facebook_id', 'instagram', 'twitter', 'fsq_category_ids',
#        'fsq_category_labels', 'placemaker_url', 'unresolved_flags', 'geom',
#        'bbox'],
#       dtype='object')

# %%
df_places
# Out:
#                fsq_place_id  \
# 0  59cf6cf9c876c857cfa4fa95
# 1  564fac1360b269848aa2ef78
# 2  85320866b2ec4603f504438b
# 3  6a73beac7eb64273d8aa7e63
# 4  8ea66c524db84cf7fcbfff2e
# 5  bc10bd0488af4805136e727d
# 6  8f0ee1f3295c46a8718c0113
# 7  16ba44b2f8154621da6019e6
# 8  59fade17840fc22443281ea8
# 9  971ea6e372fa48fefc30656d
#
#                                                 name  latitude  longitude  \
# 0                                         Assila Spa       NaN        NaN
# 1                                     Foodtown South       NaN        NaN
# 2                           Aguilar Quiroz Alejandro       NaN        NaN
# 3  АТТРАКЦИОНЫ ПАРКА КУЛЬТУРЫ И ОТДЫХА СЕВЕРНОЕ Т...       NaN        NaN
# 4                             Farmacias de Similares       NaN        NaN
# 5         Zhejiang Aoke Pearlescent Pigment Co.,Ltd.       NaN        NaN
# 6                                САНЛАЙТ ГРУПП ФИРМА       NaN        NaN
# 7                             Ruiz Gonzalez Gabriela       NaN        NaN
# 8                                         cotage 364       NaN        NaN
# 9                               Mohd Kqamil Abd Aziz       NaN        NaN
#
#                                              address          locality  \
# 0                                                NaN            Jeddah
# 1                                  858 South Dill St      East Bernard
# 2                                   Cll Argelia 20 2           Uruapan
# 3                                     Свободы Ул. 56            Москва
# 4                Avenida Enida Insurgentes Sur 1991F  Ciudad de México
# 5                       No. 2 Sanjie Industrial Zone               NaN
# 6                 Нагорная Ул., д. 20 корп. 6, оф. 6            Москва
# 7                       Cll Cascada de Agua Azul 535  Tuxtla Gutiérrez
# 8                                                NaN           America
# 9  9 Bloka2 Pusat Dagang Setia Jaya Jalan Klang L...     Petaling Jaya
#
#              region  postcode  admin_region  post_town  ...  email  \
# 0            Makkah   23326.0           NaN        NaN  ...    NaN
# 1                TX   77435.0           NaN        NaN  ...    NaN
# 2         Michoacan       NaN           NaN        NaN  ...    NaN
# 3            Москва       NaN           NaN        NaN  ...    NaN
# 4  Ciudad de México       NaN           NaN        NaN  ...    NaN
# 5               NaN  312452.0           NaN        NaN  ...    NaN
# 6            Москва  117186.0           NaN        NaN  ...    NaN
# 7           Chiapas       NaN           NaN        NaN  ...    NaN
# 8           Limburg    5966.0           NaN        NaN  ...    NaN
# 9          Selangor   47300.0           NaN        NaN  ...    NaN
#
#   facebook_id instagram twitter              fsq_category_ids  \
# 0         NaN       NaN     NaN                           NaN
# 1         NaN       NaN     NaN                           NaN
# 2         NaN       NaN     NaN  ['63be6904847c3692a84b9b3e']
# 3         NaN       NaN     NaN  ['4d4b7105d754a06379d81259']
# 4         NaN       NaN     NaN  ['5745c2e4498e11e7bccabdbd']
# 5         NaN       NaN     NaN                           NaN
# 6         NaN       NaN     NaN                           NaN
# 7         NaN       NaN     NaN  ['63be6904847c3692a84b9b36']
# 8         NaN       NaN     NaN                           NaN
# 9         NaN       NaN     NaN                           NaN
#
#                                  fsq_category_labels  \
# 0                                                NaN
# 1                                                NaN
# 2  ['Business and Professional Services > Financi...
# 3                      ['Travel and Transportation']
# 4                             ['Retail > Drugstore']
# 5                                                NaN
# 6                                                NaN
# 7  ['Business and Professional Services > Constru...
# 8                                                NaN
# 9                                                NaN
#
#                                       placemaker_url  unresolved_flags  geom  \
# 0  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 1  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 2  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 3  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 4  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 5  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 6  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 7  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 8  https://foursquare.com/placemakers/review-plac...               NaN   NaN
# 9  https://foursquare.com/placemakers/review-plac...               NaN   NaN
#
#    bbox
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
#
# [10 rows x 27 columns]

# %%
df_categories
# Out:
#                    category_id  category_level  \
# 0     63be6904847c3692a84b9c0c               3
# 1     52960eda3cf9994f4e043acc               5
# 2     4bf58dd8d48988d117951735               3
# 3     56aa371be4b08b9a8d57350e               4
# 4     4bf58dd8d48988d189941735               3
# ...                        ...             ...
# 1240  55a5a1ebe4b013909087cb83               4
# 1241  5bae9231bedf3950379f89e1               4
# 1242  58daa1558bbb0b01f18ec1c4               5
# 1243  56aa371be4b08b9a8d5734fc               3
# 1244  52e81612bcbc57f1066b79f8               3
#
#                        category_name  \
# 0                        Hockey Club
# 1     Indonesian Meatball Restaurant
# 2                        Candy Store
# 3                   Satay Restaurant
# 4                   Football Stadium
# ...                              ...
# 1240               Puglia Restaurant
# 1241             Egyptian Restaurant
# 1242               Gilaki Restaurant
# 1243                Confucian Temple
# 1244            Pakistani Restaurant
#
#                                          category_label  \
# 0          Sports and Recreation > Hockey > Hockey Club
# 1     Dining and Drinking > Restaurant > Asian Resta...
# 2       Retail > Food and Beverage Retail > Candy Store
# 3     Dining and Drinking > Restaurant > Asian Resta...
# 4     Arts and Entertainment > Stadium > Football St...
# ...                                                 ...
# 1240  Dining and Drinking > Restaurant > Italian Res...
# 1241  Dining and Drinking > Restaurant > Middle East...
# 1242  Dining and Drinking > Restaurant > Middle East...
# 1243  Community and Government > Spiritual Center > ...
# 1244  Dining and Drinking > Restaurant > Pakistani R...
#
#             level1_category_id      level1_category_name  \
# 0     4f4528bc4b90abdf24c9de85     Sports and Recreation
# 1     63be6904847c3692a84b9bb5       Dining and Drinking
# 2     4d4b7105d754a06378d81259                    Retail
# 3     63be6904847c3692a84b9bb5       Dining and Drinking
# 4     4d4b7104d754a06370d81259    Arts and Entertainment
# ...                        ...                       ...
# 1240  63be6904847c3692a84b9bb5       Dining and Drinking
# 1241  63be6904847c3692a84b9bb5       Dining and Drinking
# 1242  63be6904847c3692a84b9bb5       Dining and Drinking
# 1243  63be6904847c3692a84b9b9a  Community and Government
# 1244  63be6904847c3692a84b9bb5       Dining and Drinking
#
#             level2_category_id      level2_category_name  \
# 0     63be6904847c3692a84b9c0b                    Hockey
# 1     4d4b7105d754a06374d81259                Restaurant
# 2     4bf58dd8d48988d1f9941735  Food and Beverage Retail
# 3     4d4b7105d754a06374d81259                Restaurant
# 4     4bf58dd8d48988d184941735                   Stadium
# ...                        ...                       ...
# 1240  4d4b7105d754a06374d81259                Restaurant
# 1241  4d4b7105d754a06374d81259                Restaurant
# 1242  4d4b7105d754a06374d81259                Restaurant
# 1243  4bf58dd8d48988d131941735          Spiritual Center
# 1244  4d4b7105d754a06374d81259                Restaurant
#
#             level3_category_id       level3_category_name  \
# 0     63be6904847c3692a84b9c0c                Hockey Club
# 1     4bf58dd8d48988d142941735           Asian Restaurant
# 2     4bf58dd8d48988d117951735                Candy Store
# 3     4bf58dd8d48988d142941735           Asian Restaurant
# 4     4bf58dd8d48988d189941735           Football Stadium
# ...                        ...                        ...
# 1240  4bf58dd8d48988d110941735         Italian Restaurant
# 1241  4bf58dd8d48988d115941735  Middle Eastern Restaurant
# 1242  4bf58dd8d48988d115941735  Middle Eastern Restaurant
# 1243  56aa371be4b08b9a8d5734fc           Confucian Temple
# 1244  52e81612bcbc57f1066b79f8       Pakistani Restaurant
#
#             level4_category_id   level4_category_name  \
# 0                          NaN                    NaN
# 1     4deefc054765f83613cdba6f  Indonesian Restaurant
# 2                          NaN                    NaN
# 3     56aa371be4b08b9a8d57350e       Satay Restaurant
# 4                          NaN                    NaN
# ...                        ...                    ...
# 1240  55a5a1ebe4b013909087cb83      Puglia Restaurant
# 1241  5bae9231bedf3950379f89e1    Egyptian Restaurant
# 1242  52e81612bcbc57f1066b79f7     Persian Restaurant
# 1243                       NaN                    NaN
# 1244                       NaN                    NaN
#
#             level5_category_id            level5_category_name  \
# 0                          NaN                             NaN
# 1     52960eda3cf9994f4e043acc  Indonesian Meatball Restaurant
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 1240                       NaN                             NaN
# 1241                       NaN                             NaN
# 1242  58daa1558bbb0b01f18ec1c4               Gilaki Restaurant
# 1243                       NaN                             NaN
# 1244                       NaN                             NaN
#
#      level6_category_id level6_category_name
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
# ...                 ...                  ...
# 1240                NaN                  NaN
# 1241                NaN                  NaN
# 1242                NaN                  NaN
# 1243                NaN                  NaN
# 1244                NaN                  NaN
#
# [1245 rows x 16 columns]

# %%
df_categories.columns
# Out:
# Index(['category_id', 'category_level', 'category_name', 'category_label',
#        'level1_category_id', 'level1_category_name', 'level2_category_id',
#        'level2_category_name', 'level3_category_id', 'level3_category_name',
#        'level4_category_id', 'level4_category_name', 'level5_category_id',
#        'level5_category_name', 'level6_category_id', 'level6_category_name'],
#       dtype='object')
